# %%
import numpy as np
import networkx as nx
import matplotlib as mpl
from datetime import datetime
import matplotlib.pyplot as plt
from itertools import combinations
from joblib import Parallel, delayed
from networkx.utils import py_random_state
import random, time, pickle, multiprocessing, matplotlib, copy, itertools

# %% [markdown]
# ## Bulding the Network

# %%
def regular_clique(number_of_nodes, average_degree, clique_size):
    N, K, c = number_of_nodes, average_degree, clique_size
    if K % (c-1) != 0:
        raise Exception('This configuration is not possile')
    else:
        k = int(K/(c-1))
        m = int(N*k/c)
        nodes = [(u, _k) for u in range(N) for _k in range(k)]
        random.shuffle(nodes)
        cliques = [(u, _k) for u in range(m) for _k in range(c)]
        l = list(zip(cliques, nodes))
        my_list = [j[1][0] for j in l]
        node_collections = [my_list[i:i+c] for i in range(0, len(my_list), c)]
        g = nx.Graph()
        for col in node_collections:
            g.add_edges_from(itertools.combinations(col, 2))
        g.remove_edges_from(nx.selfloop_edges(g))
    return g

# %% [markdown]
# ## Contact Tracing Process

# %%
def comp_g(g, compartment_name):
    '''
        returns nodes in compartment compartment_name
    '''
    return [node for node in g.nodes() if g.nodes()[node]['type'] == compartment_name]


def contact_tracing(G, alpha, p):
    '''
        returns number of nodes in different compartments S, I, Q, R
        after runing the SIR+Q process
    '''
    N = len(G)
    infection_seed = random.randint(0, N-1)
    compartments = dict([(infection_seed,{'type':'I'})] + [(node,{'type':'S'}) for node in G.nodes() if node != infection_seed])
    nx.set_node_attributes(G, compartments)
    
    new_seeds = {infection_seed} 
    while new_seeds:
        #check if there is no infection left
        t = [quarantine_infection(seed, G, alpha, p) for seed in new_seeds]
        new_seeds = {item for sublist in t for item in sublist}
    
    S, I, R, Q = comp_g(G, 'S'), comp_g(G, 'I'), comp_g(G, 'R'), comp_g(G, 'Q')

    return [len(S)/N, len(I)/N, len(R)/N, len(Q)/N, len(R)/N + p* len(Q)/N]


def quarantine_infection(infected_node, G, alpha, p):
    '''
        begins from new ifected nodes, yields new infected nodes
        while putting nodes in the right compartment
    '''
    new_infected_nodes = []
    for ne in G[infected_node]:
        if G.nodes()[ne]['type'] == 'S':
            if random.random() <= alpha:
                G.nodes()[ne]['type'] = 'Q'
            else:
                if random.random() <= p:
                    G.nodes()[ne]['type'] = 'I'
                    new_infected_nodes.append(ne)
    G.nodes()[infected_node]['type'] = 'R'
    
    return new_infected_nodes

# %%
average_degree = 6 
c_1_list = [2,3,4]

p_range = np.linspace(0.2,0.70, 40)
alphas =  [0 , .25, 0.5]

ens = 10**2 #ensembel size
N = 10**4 

fig = plt.figure()
gs = fig.add_gridspec(3, hspace=0)
axs = gs.subplots(sharex=True, sharey=True)
Gs = [regular_clique(N, average_degree, c) for c in c_1_list]

for _al in range(len(alphas)):
    CT = lambda p_range, G, alpha: [contact_tracing(G, alpha, p)[4] for p in p_range]
    data = [np.mean(np.array(Parallel(n_jobs = max(12, multiprocessing.cpu_count()))(delayed(CT)(p_range, G, alphas[_al]) for en in range(ens))), axis = 0) for G in Gs]
    #np.save(str(N)+'_'+str(alphas[_al])+'fig3A', data)
    
    colors = ['r', 'g', 'b', 'm'] 
    axs[_al].plot(p_range, data[0], marker ='*', label = r'$c = 2$', color = colors[0])
    axs[_al].plot(p_range, data[1], marker = 6, label =r'$c = 3$', color = colors[1])
    axs[_al].plot(p_range, data[2], marker= 'h', label = r'$c = 4$', color = colors[2])
    if _al == 2:
        axs[_al].set_yticks([.1, .2, .3])
    else:
        axs[_al].set_yticks([0, .1, .2])
    axs[_al].set_ylim(-0.01, .3)
    axs[_al].set_xlim(0.2, .7)
    axs[_al].set_xlabel(r'$p$', fontsize = 15)

axs[0].legend(fontsize = 15)
fig.suptitle(r'Outbreak Size', fontsize = 15)
plt.savefig(str(N)+'_'+str(alphas)+'_fig3A.pdf')
# Out:
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     import distutils  # noqa
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     mod = importlib.import_module('setuptools._distutils')
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     return method()
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     mod = importlib.import_module('setuptools._distutils')
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     return method()
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     import setuptools.version
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#     import setuptools.version
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     f(*args, **kwargs)
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     f(*args, **kwargs)
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     from .backports import concurrency_safe_rename
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     __import__(pkg_name)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/__init__.py", line 113, in <module>
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/memory.py", line 32, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
# ...
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_store_backends.py", line 15, in <module>
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     from .backports import concurrency_safe_rename
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/backports.py", line 22, in <module>
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     import distutils  # noqa
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 97, in find_spec
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     return method()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/_distutils_hack/__init__.py", line 108, in spec_for_distutils
#     mod = importlib.import_module('setuptools._distutils')
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     working_set = WorkingSet._build_master()
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     for dist in factory(fullpath):
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/__init__.py", line 16, in <module>
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     import setuptools.version
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/setuptools/version.py", line 1, in <module>
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     import pkg_resources
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3260, in <module>
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     def _initialize_master_working_set():
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3234, in _call_aside
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2161, in distributions_from_metadata
#     f(*args, **kwargs)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 3272, in _initialize_master_working_set
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     yield Distribution.from_location(
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2609, in from_location
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     working_set = WorkingSet._build_master()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 572, in _build_master
#     return cls(
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2590, in __init__
#     ws = cls()
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 565, in __init__
#     self._version = safe_version(version)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 1342, in safe_version
#     self.add_entry(entry)
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 621, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2096, in find_on_path
#     return str(packaging.version.Version(version))
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/_vendor/packaging/version.py", line 301, in __str__
#     for dist in factory(fullpath):
#   File "/share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/pkg_resources/__init__.py", line 2154, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
#     parts.append(".".join(str(x) for x in self.release))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     974 if getattr(self._backend, 'supports_timeout', False):
# --> 975     self._output.extend(job.get(timeout=self.timeout))
#     976 else:
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      15 for _al in range(len(alphas)):
#      16     CT = lambda p_range, G, alpha: [contact_tracing(G, alpha, p)[4] for p in p_range]
# ---> 17     data = [np.mean(np.array(Parallel(n_jobs = max(12, multiprocessing.cpu_count()))(delayed(CT)(p_range, G, alphas[_al]) for en in range(ens))), axis = 0) for G in Gs]
#      18     #np.save(str(N)+'_'+str(alphas[_al])+'fig3A', data)
#      20     colors = ['r', 'g', 'b', 'm']
#
# Cell In[6], line 17, in <listcomp>(.0)
#      15 for _al in range(len(alphas)):
#      16     CT = lambda p_range, G, alpha: [contact_tracing(G, alpha, p)[4] for p in p_range]
# ---> 17     data = [np.mean(np.array(Parallel(n_jobs = max(12, multiprocessing.cpu_count()))(delayed(CT)(p_range, G, alphas[_al]) for en in range(ens))), axis = 0) for G in Gs]
#      18     #np.save(str(N)+'_'+str(alphas[_al])+'fig3A', data)
#      20     colors = ['r', 'g', 'b', 'm']
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/parallel.py:997, in Parallel.retrieve(self)
#     991 if (backend is not None and
#     992         hasattr(backend, 'abort_everything')):
#     993     # If the backend is managed externally we need to make sure
#     994     # to leave it in a working state to allow for future jobs
#     995     # scheduling.
#     996     ensure_ready = self._managed_backend
# --> 997     backend.abort_everything(ensure_ready=ensure_ready)
#     998 raise
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/_parallel_backends.py:586, in LokyBackend.abort_everything(self, ensure_ready)
#     583 def abort_everything(self, ensure_ready=True):
#     584     """Shutdown the workers and restart a new one with the same parameters
#     585     """
# --> 586     self._workers.terminate(kill_workers=True)
#     587     self._workers = None
#     589     if ensure_ready:
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/executor.py:74, in MemmappingExecutor.terminate(self, kill_workers)
#      73 def terminate(self, kill_workers=False):
# ---> 74     self.shutdown(kill_workers=kill_workers)
#      75     if kill_workers:
#      76         # When workers are killed in such a brutal manner, they cannot
#      77         # execute the finalizer of their shared memmaps. The refcount of
#    (...)
#      83
#      84         # unregister temporary resources from all contexts
#      85         with self._submit_resize_lock:
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:1199, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1196         self._executor_manager_thread_wakeup.wakeup()
#    1198 if executor_manager_thread is not None and wait:
# -> 1199     executor_manager_thread.join()
#    1201 # To reduce the risk of opening too many files, remove references to
#    1202 # objects that use file descriptors.
#    1203 self._executor_manager_thread = None
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-01/2eea7963/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loading from data

# %%
ens = 10**3
N = 2*10**6
average_degree = 6 
c_1_list = [2,3,4]
alphas =  [0   , .25, 0.5]

p_ranges = [np.linspace(0.1,0.30, 15), np.linspace(0.2,0.45, 20), np.linspace(0.3,0.7, 30)]

fig = plt.figure(figsize=(4.1, 3))
gs = fig.add_gridspec(3, hspace=0)
axs = gs.subplots(sharex=True, sharey=True)

for _al in range(len(alphas)):
    data = np.load(str(N)+'_'+str(alphas[_al])+'_regular.npy')
    
    colors = ['r', 'g', 'b', 'm'] 
    axs[_al].plot(p_ranges[_al], data[0], marker ='*', label = r'$c = 2$', color = colors[0])
    axs[_al].plot(p_ranges[_al], data[1], marker = 6, label =r'$c = 3$', color = colors[1])
    axs[_al].plot(p_ranges[_al], data[2], marker= 'h', label = r'$c = 4$', color = colors[2])
    if _al == 2:
        axs[_al].plot(p_ranges[0], [0 for _ in p_ranges[0]], marker= 'h', label = r'$c = 4$', color = colors[2])

    axs[_al].set_yticks([0, .05])
    axs[_al].set_ylim(-0.01, .1)
    axs[_al].set_xlim(0.2, .7)
    axs[_al].set_xlabel(r'$p$')

axs[0].legend(fontsize = 9)
fig.text(0.00, 0.5, 'outbreak size', ha='center', va='center', rotation='vertical')
#plt.savefig(str(N)+'_'+str(alphas)+'_friday.pdf')
# Out:
# Text(0.0, 0.5, 'outbreak size')

# %%
ens = 10**4
N = 10**5
average_degree = 6 
c_1_list = [2,3,4]
alphas =  [0   , .25, 0.5]

p_ranges = [np.linspace(0.1,0.30, 25), np.linspace(0.2,0.45, 30), np.linspace(0.3,0.7, 40)]

fig = plt.figure(figsize=(4.2, 3))
gs = fig.add_gridspec(3, hspace=0)
axs = gs.subplots(sharex=True, sharey=True)

for _al in range(len(alphas)):

    CT = lambda p_range, G, alpha: [contact_tracing(G, alpha, p)[4] for p in p_range]
    data = np.load(str(N)+'_'+str(alphas[_al])+'_regular.npy')
    
    colors = ['r', 'g', 'b', 'm'] 
    axs[_al].plot(p_ranges[_al], data[0], marker ='*', label = r'$c = 2$', color = colors[0])
    axs[_al].plot(p_ranges[_al], data[1], marker = 6, label =r'$c = 3$', color = colors[1])
    axs[_al].plot(p_ranges[_al], data[2], marker= 'h', label = r'$c = 4$', color = colors[2])
    for cok in [0,1,2]:
        if _al == 2:
            axs[_al].plot(np.linspace(0.1,0.30, 15), [0 for _ in np.linspace(0.1,0.30, 15)], marker= 'h', label = r'$c = 4$', color = colors[cok])
        if _al == 1:
            axs[_al].plot(np.linspace(0.1,0.20, 15), [0 for _ in np.linspace(0.1,0.20, 15)], marker= 'h', label = r'$c = 4$', color = colors[cok])
        
    axs[_al].set_ylim(0, .1)
    axs[_al].tick_params(axis='y')
    axs[_al].set_xlim(0.1, .7)
    axs[_al].set_xlabel(r'$p$')

axs[0].legend()
axs[1].set_yticks([0, 0.05])
axs[2].tick_params(axis='x')
fig.text(0.00, 0.5, 'Outbreak Size', ha='center', va='center', rotation='vertical')

plt.savefig(str(N)+'_'+str(alphas)+'_f33.pdf')
